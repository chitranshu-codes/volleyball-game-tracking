# %%
import os

# %%
# !pip install ultralytics

# %%
# !mkdir PlayerRefereeBallDetection

# %%
os.chdir('/content/PlayerRefereeBallDetection')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("my-projects-hybl4").project("volleyball-game-tracking")
version = project.version(3)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8x.pt data='/content/PlayerRefereeBallDetection/Volleyball-Game-Tracking-3/data.yaml' epochs=15 imgsz=640 batch=8 # resolution 640x640
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
